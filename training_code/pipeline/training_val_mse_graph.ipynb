# %%
import pandas as pd
import matplotlib.pyplot as plt
import cv2 as cv

# %%
df = pd.read_csv("training_log_new_diff_scratch_wscheduler0.85_seed22222_lr{lr}_trainloss{train_loss:.5f}_epoch{epochs}.csv")
df['epoch'] = df['epoch'] + 1  # Start epochs from 1

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(df["epoch"], df["mse"], label="Train MSE")
ax.plot(df["epoch"], df["val_mse"], label="Validation MSE")

ax.set_xlabel("Epochs")
ax.set_ylabel("MSE")
ax.set_title("Train vs Validation MSE Over Epochs")

ax.legend(loc="best")  # Explicit legend placement

# Fix layout and background issues
fig.tight_layout()
fig.patch.set_facecolor('white')  # Ensuring a white background
plt.savefig("train_vs_val_mse.png", bbox_inches='tight', dpi=300, facecolor='white')
