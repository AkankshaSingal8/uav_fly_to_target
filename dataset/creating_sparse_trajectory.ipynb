# %%
import os
from typing import Iterable, Dict

import csv

import numpy as np
from matplotlib.image import imread
from tqdm import tqdm
from PIL import Image

import seaborn as sns
import pandas as pd
import scipy.io

# %%
root = "original_dataset"
file_ending = 'png'
file_name = "data_out.csv"
length_root = len(os.listdir(root))

result_directory = "coreset"

# %%
# Creating sparse subset of the trajectory
intervals = [25, 4, 8, 12, 16, 24, 28, 30]

for interval in intervals:
    length_dest = len(os.listdir(result_directory))
    print("Print length dest", length_dest)
    for i in range(len(os.listdir(root))):
        directory = i + 1
        print("Processing directory", directory)
        new_directory = length_dest + directory
        print("Creating directory", new_directory)
        new_directory_path = f"{result_directory}/{new_directory}"
        if not os.path.exists(new_directory_path):
            os.makedirs(new_directory_path)
            
    
        csv_file_name = f"{root}/{str(directory)}/{file_name}"
        labels = np.genfromtxt(csv_file_name, delimiter=',', skip_header=1, dtype=np.float32)

        image_files = [fn for fn in os.listdir(f"./{root}/{str(directory)}") if file_ending in fn]
        n_images = len(image_files)
        print("Number of images:", n_images)
        sorted_image_files = list(range(1, n_images + 1))

        # Select every (interval)th image
        selected_images_files = sorted_image_files[::interval]
        if len(selected_images_files) > 44:
            selected_images_files = selected_images_files[:44]
            selected_images_files.extend([n_images] * 20)
        else:
            selected_images_files = selected_images_files[:]
            selected_images_files.extend([n_images] * (64 - len(selected_images_files)))


        
        velocity_values = [0.0, 0.0, 0.0, 0.0]
        selected_labels = labels[::interval].tolist()
        if len(selected_labels) > 44:
            selected_labels = selected_labels[:44]
            selected_labels.extend([velocity_values] * 20)
        
        else:
            selected_labels = selected_labels[:]
            selected_labels.extend([velocity_values] * (64 - len(selected_labels)))
            
        
        print(len(selected_images_files), len(selected_labels))
        
        # last image
        
        # print(selected_images_files, selected_labels)

        for i in range(len(selected_images_files)):
            image_file = selected_images_files[i]
            image_path = f"{root}/{str(directory)}/Image{str(image_file)}.png"
            img = Image.open(image_path)
        
            new_filename =  f"{new_directory_path}/Image{str(i + 1)}.png"
        
            img.save(new_filename)
        
        columns = ['vx', 'vy', 'vz', 'omega_z']
        df = pd.DataFrame(selected_labels, columns=columns)
        df.to_csv(f"{new_directory_path}/{file_name}", index=False)
# Out:
# Print length dest 300
# Processing directory 1
# Creating directory 301
# Number of images: 593
# 64 64
# Processing directory 2
# Creating directory 302
# Number of images: 542
# 64 64
# Processing directory 3
# Creating directory 303
# Number of images: 497
# 64 64
# Processing directory 4
# Creating directory 304
# Number of images: 520
# 64 64
# Processing directory 5
# Creating directory 305
# Number of images: 568
# 64 64
# Processing directory 6
# Creating directory 306
# Number of images: 825
# 64 64
# Processing directory 7
# Creating directory 307
# Number of images: 631
# 64 64
# Processing directory 8
# Creating directory 308
# Number of images: 750
# 64 64
# Processing directory 9
# Creating directory 309
# Number of images: 768
# 64 64
# Processing directory 10
# Creating directory 310
# Number of images: 691
# 64 64
# Processing directory 11
# Creating directory 311
# Number of images: 999
# 64 64
# Processing directory 12
# Creating directory 312
# Number of images: 864
# 64 64
# Processing directory 13
# Creating directory 313
# Number of images: 914
# 64 64
# Processing directory 14
# Creating directory 314
# Number of images: 858
# 64 64
# Processing directory 15
# Creating directory 315
# Number of images: 1010
# 64 64
# Processing directory 16
# Creating directory 316
# Number of images: 796
# 64 64
# Processing directory 17
# Creating directory 317
# Number of images: 931
# 64 64
# Processing directory 18
# Creating directory 318
# Number of images: 917
# 64 64
# Processing directory 19
# Creating directory 319
# Number of images: 797
# 64 64
# Processing directory 20
# Creating directory 320
# Number of images: 882
# 64 64
# Processing directory 21
# Creating directory 321
# Number of images: 825
# 64 64
# Processing directory 22
# Creating directory 322
# Number of images: 891
# 64 64
# Processing directory 23
# Creating directory 323
# Number of images: 931
# 64 64
# Processing directory 24
# Creating directory 324
# Number of images: 894
# 64 64
# Processing directory 25
# Creating directory 325
# Number of images: 1256
# 64 64
# Processing directory 26
# Creating directory 326
# Number of images: 1302
# 64 64
# Processing directory 27
# Creating directory 327
# Number of images: 1122
# 64 64
# Processing directory 28
# Creating directory 328
# Number of images: 1166
# 64 64
# Processing directory 29
# Creating directory 329
# Number of images: 946
# 64 64
# Processing directory 30
# Creating directory 330
# Number of images: 1114
# 64 64
# Processing directory 31
# Creating directory 331
# Number of images: 590
# 64 64
# Processing directory 32
# Creating directory 332
# Number of images: 460
# 64 64
# Processing directory 33
# Creating directory 333
# Number of images: 1000
# 64 64
# Processing directory 34
# Creating directory 334
# Number of images: 549
# 64 64
# Processing directory 35
# Creating directory 335
# Number of images: 387
# 64 64
# Processing directory 36
# Creating directory 336
# Number of images: 505
# 64 64
# Processing directory 37
# Creating directory 337
# Number of images: 594
# 64 64
# Processing directory 38
# Creating directory 338
# Number of images: 679
# 64 64
# Processing directory 39
# Creating directory 339
# Number of images: 548
# 64 64
# Processing directory 40
# Creating directory 340
# Number of images: 466
# 64 64
# Processing directory 41
# Creating directory 341
# Number of images: 381
# 64 64
# Processing directory 42
# Creating directory 342
# Number of images: 372
# 64 64
# Processing directory 43
# Creating directory 343
# Number of images: 476
# 64 64
# Processing directory 44
# Creating directory 344
# Number of images: 514
# 64 64
# Processing directory 45
# Creating directory 345
# Number of images: 493
# 64 64
# Processing directory 46
# Creating directory 346
# Number of images: 685
# 64 64
# Processing directory 47
# Creating directory 347
# Number of images: 710
# 64 64
# Processing directory 48
# Creating directory 348
# Number of images: 543
# 64 64
# Processing directory 49
# Creating directory 349
# Number of images: 517
# 64 64
# Processing directory 50
# Creating directory 350
# Number of images: 461
# 64 64
# Processing directory 51
# Creating directory 351
# Number of images: 671
# 64 64
# Processing directory 52
# Creating directory 352
# Number of images: 367
# 64 64
# Processing directory 53
# Creating directory 353
# Number of images: 552
# 64 64
# Processing directory 54
# Creating directory 354
# Number of images: 344
# 64 64
# Processing directory 55
# Creating directory 355
# Number of images: 591
# 64 64
# Processing directory 56
# Creating directory 356
# Number of images: 500
# 64 64
# Processing directory 57
# Creating directory 357
# Number of images: 417
# 64 64
# Processing directory 58
# Creating directory 358
# Number of images: 603
# 64 64
# Processing directory 59
# Creating directory 359
# Number of images: 500
# 64 64
# Processing directory 60
# Creating directory 360
# Number of images: 535
# 64 64
# Processing directory 61
# Creating directory 361
# Number of images: 503
# 64 64
# Processing directory 62
# Creating directory 362
# Number of images: 607
# 64 64
# Processing directory 63
# Creating directory 363
# Number of images: 464
# 64 64
# Processing directory 64
# Creating directory 364
# Number of images: 636
# 64 64
# Processing directory 65
# Creating directory 365
# Number of images: 597
# 64 64
# Processing directory 66
# Creating directory 366
# Number of images: 409
# 64 64
# Processing directory 67
# Creating directory 367
# Number of images: 484
# 64 64
# Processing directory 68
# Creating directory 368
# Number of images: 481
# 64 64
# Processing directory 69
# Creating directory 369
# Number of images: 653
# 64 64
# Processing directory 70
# Creating directory 370
# Number of images: 537
# 64 64
# Processing directory 71
# Creating directory 371
# Number of images: 465
# 64 64
# Processing directory 72
# Creating directory 372
# Number of images: 598
# 64 64
# Processing directory 73
# Creating directory 373
# Number of images: 523
# 64 64
# Processing directory 74
# Creating directory 374
# Number of images: 445
# 64 64
# Processing directory 75
# Creating directory 375
# Number of images: 546
# 64 64
# Print length dest 375
# Processing directory 1
# Creating directory 376
# Number of images: 593
# 64 64
# Processing directory 2
# Creating directory 377
# Number of images: 542
# 64 64
# Processing directory 3
# Creating directory 378
# Number of images: 497
# 64 64
# Processing directory 4
# Creating directory 379
# Number of images: 520
# 64 64
# Processing directory 5
# Creating directory 380
# Number of images: 568
# 64 64
# Processing directory 6
# Creating directory 381
# Number of images: 825
# 64 64
# Processing directory 7
# Creating directory
# Number of images: 381
# 64 64
# Processing directory 42
# Creating directory 717
# Number of images: 372
# 64 64
# Processing directory 43
# Creating directory 718
# Number of images: 476
# 64 64
# Processing directory 44
# Creating directory 719
# Number of images: 514
# 64 64
# Processing directory 45
# Creating directory 720
# Number of images: 493
# 64 64
# Processing directory 46
# Creating directory 721
# Number of images: 685
# 64 64
# Processing directory 47
# Creating directory 722
# Number of images: 710
# 64 64
# Processing directory 48
# Creating directory 723
# Number of images: 543
# 64 64
# Processing directory 49
# Creating directory 724
# Number of images: 517
# 64 64
# Processing directory 50
# Creating directory 725
# Number of images: 461
# 64 64
# Processing directory 51
# Creating directory 726
# Number of images: 671
# 64 64
# Processing directory 52
# Creating directory 727
# Number of images: 367
# 64 64
# Processing directory 53
# Creating directory 728
# Number of images: 552
# 64 64
# Processing directory 54
# Creating directory 729
# Number of images: 344
# 64 64
# Processing directory 55
# Creating directory 730
# Number of images: 591
# 64 64
# Processing directory 56
# Creating directory 731
# Number of images: 500
# 64 64
# Processing directory 57
# Creating directory 732
# Number of images: 417
# 64 64
# Processing directory 58
# Creating directory 733
# Number of images: 603
# 64 64
# Processing directory 59
# Creating directory 734
# Number of images: 500
# 64 64
# Processing directory 60
# Creating directory 735
# Number of images: 535
# 64 64
# Processing directory 61
# Creating directory 736
# Number of images: 503
# 64 64
# Processing directory 62
# Creating directory 737
# Number of images: 607
# 64 64
# Processing directory 63
# Creating directory 738
# Number of images: 464
# 64 64
# Processing directory 64
# Creating directory 739
# Number of images: 636
# 64 64
# Processing directory 65
# Creating directory 740
# Number of images: 597
# 64 64
# Processing directory 66
# Creating directory 741
# Number of images: 409
# 64 64
# Processing directory 67
# Creating directory 742
# Number of images: 484
# 64 64
# Processing directory 68
# Creating directory 743
# Number of images: 481
# 64 64
# Processing directory 69
# Creating directory 744
# Number of images: 653
# 64 64
# Processing directory 70
# Creating directory 745
# Number of images: 537
# 64 64
# Processing directory 71
# Creating directory 746
# Number of images: 465
# 64 64
# Processing directory 72
# Creating directory 747
# Number of images: 598
# 64 64
# Processing directory 73
# Creating directory 748
# Number of images: 523
# 64 64
# Processing directory 74
# Creating directory 749
# Number of images: 445
# 64 64
# Processing directory 75
# Creating directory 750
# Number of images: 546
# 64 64
# Print length dest 750
# Processing directory 1
# Creating directory 751
# Number of images: 593
# 64 64
# Processing directory 2
# Creating directory 752
# Number of images: 542
# 64 64
# Processing directory 3
# Creating directory 753
# Number of images: 497
# 64 64
# Processing directory 4
# Creating directory 754
# Number of images: 520
# 64 64
# Processing directory 5
# Creating directory 755
# Number of images: 568
# 64 64
# Processing directory 6
# Creating directory 756
# Number of images: 825
# 64 64
# Processing directory 7
# Creating directory 757
# Number of images: 631
# 64 64
# Processing directory 8
# Creating directory 758
# Number of images: 750
# 64 64
# Processing directory 9
# Creating directory 759
# Number of images: 768
# 64 64
# Processing directory 10
# Creating directory 760
# Number of images: 691
# 64 64
# Processing directory 11
# Creating directory 761
# Number of images: 999
# 64 64
# Processing directory 12
# Creating directory 762
# Number of images: 864
# 64 64
# Processing directory 13
# Creating directory 763
# Number of images: 914
# 64 64
# Processing directory 14
# Creating directory 764
# Number of images: 858
# 64 64
# Processing directory 15
# Creating directory 765
# Number of images: 1010
# 64 64
# Processing directory 16
# Creating directory 766
# Number of images: 796
# 64 64
# Processing directory 17
# Creating directory 767
# Number of images: 931
# 64 64
# Processing directory 18
# Creating directory 768
# Number of images: 917
# 64 64
# Processing directory 19
# Creating directory 769
# Number of images: 797
# 64 64
# Processing directory 20
# Creating directory 770
# Number of images: 882
# 64 64
# Processing directory 21
# Creating directory 771
# Number of images: 825
# 64 64
# Processing directory 22
# Creating directory 772
# Number of images: 891
# 64 64
# Processing directory 23
# Creating directory 773
# Number of images: 931
# 64 64
# Processing directory 24
# Creating directory 774
# Number of images: 894
# 64 64
# Processing directory 25
# Creating directory 775
# Number of images: 1256
# 64 64
# Processing directory 26
# Creating directory 776
# Number of images: 1302
# 64 64
# Processing directory 27
# Creating directory 777
# Number of images: 1122
# 64 64
# Processing directory 28
# Creating directory 778
# Number of images: 1166
# 64 64
# Processing directory 29
# Creating directory 779
# Number of images: 946
# 64 64
# Processing directory 30
# Creating directory 780
# Number of images: 1114
# 64 64
# Processing directory 31
# Creating directory 781
# Number of images: 590
# 64 64
# Processing directory 32
# Creating directory 782
# Number of images: 460
# 64 64
# Processing directory 33
# Creating directory 783
# Number of images: 1000
# 64 64
# Processing directory 34
# Creating directory 784
# Number of images: 549
# 64 64
# Processing directory 35
# Creating directory 785
# Number of images: 387
# 64 64
# Processing directory 36
# Creating directory 786
# Number of images: 505
# 64 64
# Processing directory 37
# Creating directory 787
# Number of images: 594
# 64 64
# Processing directory 38
# Creating directory 788
# Number of images: 679
# 64 64
# Processing directory 39
# Creating directory 789
# Number of images: 548
# 64 64
# Processing directory 40
# Creating directory 790
# Number of images: 466
# 64 64
# Processing directory 41
# Creating directory 791
# Number of images: 381
# 64 64
# Processing directory 42
# Creating directory 792
# Number of images: 372
# 64 64
# Processing directory 43
# Creating directory 793
# Number of images: 476
# 64 64
# Processing directory 44
# Creating directory 794
# Number of images: 514
# 64 64
# Processing directory 45
# Creating directory 795
# Number of images: 493
# 64 64
# Processing directory 46
# Creating directory 796
# Number of images: 685
# 64 64
# Processing directory 47
# Creating directory 797
# Number of images: 710
# 64 64
# Processing directory 48
# Creating directory 798
# Number of images: 543
# 64 64
# Processing directory 49
# Creating directory 799
# Number of images: 517
# 64 64
# Processing directory 50
# Creating directory 800
# Number of images: 461
# 64 64
# Processing directory 51
# Creating directory 801
# Number of images: 671
# 64 64
# Processing directory 52
# Creating directory 802
# Number of images: 367
# 64 64
# Processing directory 53
# Creating directory 803
# Number of images: 552
# 64 64
# Processing directory 54
# Creating directory 804
# Number of images: 344
# 64 64
# Processing directory 55
# Creating directory 805
# Number of images: 591
# 64 64
# Processing directory 56
# Creating directory 806
# Number of images: 500
# 64 64
# Processing directory 57
# Creating directory 807
# Number of images: 417
# 64 64
# Processing directory 58
# Creating directory 808
# Number of images: 603
# 64 64
# Processing directory 59
# Creating directory 809
# Number of images: 500
# 64 64
# Processing directory 60
# Creating directory 810
# Number of images: 535
# 64 64
# Processing directory 61
# Creating directory 811
# Number of images: 503
# 64 64
# Processing directory 62
# Creating directory 812
# Number of images: 607
# 64 64
# Processing directory 63
# Creating directory 813
# Number of images: 464
# 64 64
# Processing directory 64
# Creating directory 814
# Number of images: 636
# 64 64
# Processing directory 65
# Creating directory 815
# Number of images: 597
# 64 64
# Processing directory 66
# Creating directory 816
# Number of images: 409
# 64 64
# Processing directory 67
# Creating directory 817
# Number of images: 484
# 64 64
# Processing directory 68
# Creating directory 818
# Number of images: 481
# 64 64
# Processing directory 69
# Creating directory 819
# Number of images: 653
# 64 64
# Processing directory 70
# Creating directory 820
# Number of images: 537
# 64 64
# Processing directory 71
# Creating directory 821
# Number of images: 465
# 64 64
# Processing directory 72
# Creating directory 822
# Number of images: 598
# 64 64
# Processing directory 73
# Creating directory 823
# Number of images: 523
# 64 64
# Processing directory 74
# Creating directory 824
# Number of images: 445
# 64 64
# Processing directory 75
# Creating directory 825
# Number of images: 546
# 64 64
# Print length dest 825
# Processing directory 1
# Creating directory 826
# Number of images: 593
# 64 64
# Processing directory 2
# Creating directory 827
# Number of images: 542
# 64 64
# Processing directory 3
# Creating directory 828
# Number of images: 497
# 64 64
# Processing directory 4
# Creating directory 829
# Number of images: 520
# 64 64
# Processing directory 5
# Creating directory 830
# Number of images: 568
# 64 64
# Processing directory 6
# Creating directory 831
# Number of images: 825
# 64 64
# Processing directory 7
# Creating directory 832
# Number of images: 631
# 64 64
# Processing directory 8
# Creating directory 833
# Number of images: 750
# 64 64
# Processing directory 9
# Creating directory 834
# Number of images: 768
# 64 64
# Processing directory 10
# Creating directory 835
# Number of images: 691
# 64 64
# Processing directory 11
# Creating directory 836
# Number of images: 999
# 64 64
# Processing directory 12
# Creating directory 837
# Number of images: 864
# 64 64
# Processing directory 13
# Creating directory 838
# Number of images: 914
# 64 64
# Processing directory 14
# Creating directory 839
# Number of images: 858
# 64 64
# Processing directory 15
# Creating directory 840
# Number of images: 1010
# 64 64
# Processing directory 16
# Creating directory 841
# Number of images: 796
# 64 64
# Processing directory 17
# Creating directory 842
# Number of images: 931
# 64 64
# Processing directory 18
# Creating directory 843
# Number of images: 917
# 64 64
# Processing directory 19
# Creating directory 844
# Number of images: 797
# 64 64
# Processing directory 20
# Creating directory 845
# Number of images: 882
# 64 64
# Processing directory 21
# Creating directory 846
# Number of images: 825
# 64 64
# Processing directory 22
# Creating directory 847
# Number of images: 891
# 64 64
# Processing directory 23
# Creating directory 848
# Number of images: 931
# 64 64
# Processing directory 24
# Creating directory 849
# Number of images: 894
# 64 64
# Processing directory 25
# Creating directory 850
# Number of images: 1256
# 64 64
# Processing directory 26
# Creating directory 851
# Number of images: 1302
# 64 64
# Processing directory 27
# Creating directory 852
# Number of images: 1122
# 64 64
# Processing directory 28
# Creating directory 853
# Number of images: 1166
# 64 64
# Processing directory 29
# Creating directory 854
# Number of images: 946
# 64 64
# Processing directory 30
# Creating directory 855
# Number of images: 1114
# 64 64
# Processing directory 31
# Creating directory 856
# Number of images: 590
# 64 64
# Processing directory 32
# Creating directory 857
# Number of images: 460
# 64 64
# Processing directory 33
# Creating directory 858
# Number of images: 1000
# 64 64
# Processing directory 34
# Creating directory 859
# Number of images: 549
# 64 64
# Processing directory 35
# Creating directory 860
# Number of images: 387
# 64 64
# Processing directory 36
# Creating directory 861
# Number of images: 505
# 64 64
# Processing directory 37
# Creating directory 862
# Number of images: 594
# 64 64
# Processing directory 38
# Creating directory 863
# Number of images: 679
# 64 64
# Processing directory 39
# Creating directory 864
# Number of images: 548
# 64 64
# Processing directory 40
# Creating directory 865
# Number of images: 466
# 64 64
# Processing directory 41
# Creating directory 866
# Number of images: 381
# 64 64
# Processing directory 42
# Creating directory 867
# Number of images: 372
# 64 64
# Processing directory 43
# Creating directory 868
# Number of images: 476
# 64 64
# Processing directory 44
# Creating directory 869
# Number of images: 514
# 64 64
# Processing directory 45
# Creating directory 870
# Number of images: 493
# 64 64
# Processing directory 46
# Creating directory 871
# Number of images: 685
# 64 64
# Processing directory 47
# Creating directory 872
# Number of images: 710
# 64 64
# Processing directory 48
# Creating directory 873
# Number of images: 543
# 64 64
# Processing directory 49
# Creating directory 874
# Number of images: 517
# 64 64
# Processing directory 50
# Creating directory 875
# Number of images: 461
# 64 64
# Processing directory 51
# Creating directory 876
# Number of images: 671
# 64 64
# Processing directory 52
# Creating directory 877
# Number of images: 367
# 64 64
# Processing directory 53
# Creating directory 878
# Number of images: 552
# 64 64
# Processing directory 54
# Creating directory 879
# Number of images: 344
# 64 64
# Processing directory 55
# Creating directory 880
# Number of images: 591
# 64 64
# Processing directory 56
# Creating directory 881
# Number of images: 500
# 64 64
# Processing directory 57
# Creating directory 882
# Number of images: 417
# 64 64
# Processing directory 58
# Creating directory 883
# Number of images: 603
# 64 64
# Processing directory 59
# Creating directory 884
# Number of images: 500
# 64 64
# Processing directory 60
# Creating directory 885
# Number of images: 535
# 64 64
# Processing directory 61
# Creating directory 886
# Number of images: 503
# 64 64
# Processing directory 62
# Creating directory 887
# Number of images: 607
# 64 64
# Processing directory 63
# Creating directory 888
# Number of images: 464
# 64 64
# Processing directory 64
# Creating directory 889
# Number of images: 636
# 64 64
# Processing directory 65
# Creating directory 890
# Number of images: 597
# 64 64
# Processing directory 66
# Creating directory 891
# Number of images: 409
# 64 64
# Processing directory 67
# Creating directory 892
# Number of images: 484
# 64 64
# Processing directory 68
# Creating directory 893
# Number of images: 481
# 64 64
# Processing directory 69
# Creating directory 894
# Number of images: 653
# 64 64
# Processing directory 70
# Creating directory 895
# Number of images: 537
# 64 64
# Processing directory 71
# Creating directory 896
# Number of images: 465
# 64 64
# Processing directory 72
# Creating directory 897
# Number of images: 598
# 64 64
# Processing directory 73
# Creating directory 898
# Number of images: 523
# 64 64
# Processing directory 74
# Creating directory 899
# Number of images: 445
# 64 64
# Processing directory 75
# Creating directory 900
# Number of images: 546
# 64 64
